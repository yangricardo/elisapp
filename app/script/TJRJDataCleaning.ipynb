# %%
import os, sys, django, pandas as pd , numpy as np, requests, json, re, itertools, ftfy
from django.db.models import Q
from utils import TJData, setup_env, ElisAPI
# configura notebook para se utilizar recursos do django, se necessário
setup_env() 
from api import models as tj
# objeto para interagir com a minha API
api = ElisAPI('http://0.0.0.0:8000','elisdbadmin','elisdbpassword')


def retry_post(resource, r_post):
    r_post_old = r_post
    if r_post:
        r_post_retry = api.retry_post(resource,r_post)
        return r_post_old, r_post_retry
    return r_post_old

# %% [markdown]
# ### Comarca
# O bloco de código abaixo foi utilizado para analisar e decidir visualmente qual planilha referente a comarcas será utilizada, a planilha mapeada por `comarca` possui a coluna `COD_SERV` possui codigos distintos dos referenciados por demais planilhas
# ```
# com_1 = TJData.read_csv(TJData.csv['comarca'],usecols=['COD_COM','NOME','NOME_REDU','COD_TJ'])
# com_2 = TJData.read_csv(TJData.csv['comarca_2'], usecols=['COD_COMA','DESC_COMA','COD_TJ','DESC_REDU'])
# com = pd.merge(left=com_1,right=com_2,how='inner',left_on='NOME_REDU', right_on='DESC_REDU')
# ```
#
# #### Tratamento de dados

# %% [raw]
# comarcas = TJData.read_csv(TJData.csv['comarca_2'], usecols=['COD_COMA','DESC_COMA','DESC_REDU'])
# # converte o cabeçalho para caixa baixa
# comarcas = comarcas.rename(columns=lambda x: str(x).lower())
# # filtra as linhas com cod_coma nulas
# comarcas = comarcas[~pd.isnull(comarcas.cod_coma)]
# # converte de float para int
# comarcas.cod_coma = comarcas.cod_coma.astype(int)
# # codifica os bytes da string para utf8
# comarcas.desc_coma = TJData.to_utf8_bytes(comarcas.desc_coma)
# comarcas.desc_redu = TJData.to_utf8_bytes(comarcas.desc_redu)
# # converte o dataframe em objeto json (lista de dicionarios)
# comarcas = TJData.to_json(comarcas)
# # envia requisições post concorrentes
# r = api.concurrent_request(api.post,'comarcas',comarcas)

# %% [markdown]
# ### Serventia
#
# ```
# serv_1 = TJData.read_csv(TJData.csv['serventia_2'], usecols=['COD_SERV','DESC_SERV','COD_COMA','DESC_ABRE','DESC_REDU'] )
# serv_2 = TJData.read_csv(TJData.csv['serventias_full'], usecols=['COD_SERV','DESC_SERV','COD_COMA','DESC_ABRE','DESC_REDU'])
# serv = pd.merge(left=serv_1,right=serv_2,how='inner',left_on='COD_SERV', right_on='COD_SERV')
# serv_outer = pd.merge(left=serv_1,right=serv_2,how='outer',left_on='COD_SERV', right_on='COD_SERV')
# ```
# #### Tratamento de dados

# %% [raw]
# serventias = TJData.read_csv(TJData.csv['serventia_2'], usecols=['COD_SERV','DESC_SERV','COD_COMA','DESC_ABRE'] )
# serventias = serventias.rename(columns=lambda x: str(x).lower())
# # ajusta cod_coma para referenciar o atributo comarca(FK) de serventia
# serventias = serventias.rename(columns={'cod_coma':'comarca'})
# serventias = serventias[~pd.isnull(serventias.comarca)]
# serventias.comarca = serventias.comarca.astype(int)
# # elimina codigos de comarca não existentes
# serventias = serventias.query("comarca != 888 & comarca != 999")
# serventias.desc_serv =  TJData.to_utf8_bytes(serventias.desc_serv)
# serventias.desc_abre =  TJData.to_utf8_bytes(serventias.desc_abre)
# serventias = TJData.to_json(serventias)
# r = api.concurrent_request(api.post,'serventias',serventias)

# %% [markdown]
# ### Competencias

# %% [raw]
# competencias = TJData.read_csv(TJData.csv['competencia'], usecols=['COD_COMP', 'DESC_COMP', 'DESC_RES'])
# competencias = competencias.rename(columns=lambda x: str(x).lower())
# competencias.cod_comp = competencias.cod_comp.astype(int)
# competencias.desc_comp = TJData.to_utf8_bytes(competencias.desc_comp)
# competencias.desc_res= TJData.to_utf8_bytes(competencias.desc_res)
# competencias = TJData.to_json(competencias)
# r = api.concurrent_request(api.post,'competencias',competencias)

# %% [raw]
# competencias_erros = api.get_erros(r,201)
# competencias_erros

# %% [markdown]
# ### Tipo Personagem

# %% [raw]
# tp_pers = TJData.read_csv(TJData.csv['tipo_personagem'], usecols=['COD_TIP_PERS', 'DESC_PERS', 'TIPO_PART','COD_TIP_PERS_INV'])
# tp_pers = tp_pers.rename(columns=lambda x: str(x).lower())
# tp_pers.cod_tip_pers_inv = TJData.nan_to_int(tp_pers.cod_tip_pers_inv)
# tp_pers = tp_pers.sort_values(by='cod_tip_pers', ascending=True)
# tp_pers.desc_pers = TJData.to_utf8_bytes(tp_pers.desc_pers)
# tp_pers.tipo_part = TJData.to_utf8_bytes(tp_pers.tipo_part)
# # divide a requisição devido a referencia circular
# tp_pers_post = TJData.to_json(tp_pers.drop(columns=['cod_tip_pers_inv']))
# tp_pers_patch = TJData.to_json(tp_pers.drop(columns=['desc_pers','tipo_part']))
# r_post = api.concurrent_request(api.post,'tipospersonagem',tp_pers_post)
# r_patch = api.concurrent_request(api.patch,'tipospersonagem',tp_pers_patch,detail='cod_tip_pers')

# %% [markdown]
# ### Assunto

# %% [raw]
# assuntos = TJData.read_csv(TJData.csv['assunto'], usecols=['COD_ASSUNTO', 'COD_ASSUNTO_PAI', 'DESCR'])
# assuntos = assuntos.rename(columns=lambda x: str(x).lower())
# assuntos = assuntos.rename(columns={'cod_assunto_pai':'assunto_pai'})
# assuntos = assuntos.sort_values(by='cod_assunto', ascending=True)
# assuntos.assunto_pai = TJData.nan_to_int(assuntos.assunto_pai)
# assuntos.descr = TJData.to_utf8_bytes(assuntos.descr)
# assuntos_post = TJData.to_json(assuntos.drop(columns=['assunto_pai']))
# assuntos_patch = TJData.to_json(assuntos.drop(columns=['descr']))
# r_post = api.concurrent_request(api.post,'assuntos',assuntos_post)
# r_patch = api.concurrent_request(api.patch,'assuntos',assuntos_patch,detail='cod_assunto')

# %% [raw]
# assunto_post_erros = api.get_erros(r_post,201)
# assunto_post_erros

# %% [raw]
# assunto_patch_erros = api.get_erros(r_patch,200)
# assunto_patch_erros

# %% [markdown]
# ### Classe

# %% [raw]
# classes = TJData.read_csv(TJData.csv['classe'], usecols=['COD_CLASSE', 'DESCR', 'COD_CLASSE_PAI','COD_PERS_ATIVO','COD_PERS_PASSIVO'])
# classes = classes.rename(columns=lambda x : str(x).lower())
# classes = classes.rename(columns={'cod_classe_pai':'classe_pai'})
# classes = classes.sort_values(by='cod_classe', ascending=True)
# classes.classe_pai = TJData.nan_to_int(classes.classe_pai)
# classes.cod_pers_ativo = TJData.nan_to_int(classes.cod_pers_ativo)
# classes.cod_pers_passivo = TJData.nan_to_int(classes.cod_pers_passivo)
# classes.descr = TJData.to_utf8_bytes(classes.descr)
# classes_post = TJData.to_json(classes.drop(columns=['classe_pai','cod_pers_ativo','cod_pers_passivo']))
# classes_patch = TJData.to_json(classes.drop(columns=['descr']))
# r_post = api.concurrent_request(api.post,'classes',classes_post)
# r_patch = api.concurrent_request(api.patch,'classes',classes_patch,detail='cod_classe')

# %% [markdown]
# ### Classe assunto

# %% [raw]
# classes_assuntos = TJData.read_csv(TJData.csv['classe_assunto_2'], usecols=['COD_CLASSE','COD_ASSUNTO'])
# classes_assuntos = classes_assuntos.rename(columns={'COD_CLASSE':'classe','COD_ASSUNTO':'assunto'})
#
# # # O bloco comentado auxilia na execução desse script caso alguma execução tenha falhado, filtra os registros ja cadastrados
# # classes = list(map(lambda x : x['cod_classe'], api.response_to_json(api.get('classes'))))
# # assuntos = list(map(lambda x : x['cod_assunto'], api.response_to_json(api.get('assuntos'))))
# # classes_assuntos = classes_assuntos[(classes_assuntos.classe.isin(classes)) & (classes_assuntos.assunto.isin(assuntos))]
# # ca_db = pd.DataFrame(api.response_to_json(api.get('classesassuntos')))
# # diff = list(set(zip(classes_assuntos.classe, classes_assuntos.assunto)) - set(zip(ca_db.classe, ca_db.assunto)))
# # classes_assuntos = pd.DataFrame(diff, columns=['classe','assunto'])
# classes_assuntos = TJData.to_json(classes_assuntos)
# classes_assuntos = api.split_list(classes_assuntos,1000)
# r = api.concurrent_request(api.post,'classesassuntos',classes_assuntos)

# %% [markdown]
# ### Tipo movimento

# %% [raw]
# tp_movimento = TJData.read_csv(TJData.csv['tipo_movimento_2'], usecols=['COD_TIP_MOV', 'COD_TIP_MOV_PAI','DESCR'])
# tp_movimento = tp_movimento.rename(columns=lambda x : str(x).lower())
# tp_movimento.cod_tip_mov_pai = TJData.nan_to_int(tp_movimento.cod_tip_mov_pai)
# tp_movimento.descr = TJData.to_utf8_bytes(tp_movimento.descr)
# tp_movimento = tp_movimento.sort_values(by='cod_tip_mov', ascending=True)
# tp_movimento_post = TJData.to_json(tp_movimento.drop(columns=['cod_tip_mov_pai']))
# tp_movimento_patch = TJData.to_json(tp_movimento.drop(columns=['descr']))
# r_post = api.concurrent_request(api.post,'tiposmovimento',tp_movimento_post)
# r_patch = api.concurrent_request(api.patch,'tiposmovimento',tp_movimento_patch,detail='cod_tip_mov')

# %% [markdown]
# ### Tipo Andamento

# %% [raw]
# tp_andamento = TJData.read_csv(TJData.csv['tipo_andamento'], usecols=['COD_TIP_AND','DESCR','COD_TIP_MOV'])
# tp_andamento = tp_andamento.rename(columns=lambda x : str(x).lower())
# tp_andamento.cod_tip_mov = TJData.nan_to_int(tp_andamento.cod_tip_mov)
# tp_andamento.descr = TJData.to_utf8_bytes(tp_andamento.descr)
# tp_andamento = TJData.to_json(tp_andamento)
# r_post = api.concurrent_request(api.post,'tiposandamento',tp_andamento)

# %% [raw]
# tp_and_post_erros = api.get_erros(r_post,201)
# tp_and_post_erros

# %% [markdown]
# ### Cargo

# %% [raw]
# cargo = TJData.read_csv(TJData.csv['cargo'])
# cargo = cargo.rename(columns=lambda x: str(x).lower())
# cargo = cargo.sort_values(by='cod_carg', ascending=True)
# cargo.descr = TJData.to_utf8_bytes(cargo.descr)
# cargo = TJData.to_json(cargo)
# r = api.concurrent_request(api.post,'cargos',cargo)

# %% [markdown]
# ### Funcionário

# %% [raw]
# funcionario = TJData.read_csv(TJData.csv['funcionario'], usecols=['NUM_MATR','NOME','COD_CARG'])
# funcionario = funcionario.rename(columns=lambda x : x.lower())
# funcionario.num_matr = TJData.to_utf8_bytes(funcionario.num_matr)
# funcionario.nome = TJData.to_utf8_bytes(funcionario.nome)
# funcionario.cod_carg = TJData.nan_to_int(funcionario.cod_carg)
# # filtra Juiz(3), Juiz Leigo(19) e Juiz de Direito - Desabilitado pela SOI (98)
# funcionario = funcionario.query('cod_carg=="3" | cod_carg=="19" | cod_carg=="98"')
# funcionario = TJData.to_json(funcionario)
# r_post = api.concurrent_request(api.post,'funcionarios',funcionario)

# %% [markdown]
# ### Tipo Decisão Recurso

# %% [raw]
# tp_recursos = TJData.read_csv(TJData.csv['tipo_decisao_recurso'])
# tp_recursos = tp_recursos.rename(columns=lambda x:x.lower())
# tp_recursos.descr = TJData.to_utf8(tp_recursos.descr)
# tp_recursos = TJData.to_json(tp_recursos)
# r_post = api.concurrent_request(api.post,'tiposdecisaorecurso',tp_recursos)

# %% [raw]
# tp_rec_post_erros = api.get_erros(r_post,201)
# tp_rec_post_erros

# %% [markdown]
# ### Tipo Ato Juiz

# %% [raw]
# tp_ato_juiz = TJData.read_csv(TJData.csv['tipo_ato_juiz'])
# tp_ato_juiz = tp_ato_juiz.rename(columns=lambda x:x.lower())
# tp_ato_juiz.descr = TJData.to_utf8_bytes(tp_ato_juiz.descr)
# tp_ato_juiz = TJData.to_json(tp_ato_juiz)
# r_post = api.concurrent_request(api.post,'tiposatojuiz',tp_ato_juiz)

# %% [markdown]
# ### Ato Juiz

# %% [raw]
# # descoberta de tuplas diferentes entre as tabelas ato juiz
# atos_juiz = TJData.read_csv(TJData.csv['ato_juiz'],usecols=['COD_TIP_ATO','COD_ATO','DESCR','COD_TIP_MOV'])
# atos_juiz_2 = TJData.read_csv(TJData.csv['ato_juiz_2'],usecols=['COD_TIP_ATO','COD_ATO','DESCR','COD_TIP_MOV'])
# set_atos_juiz = set(map(lambda x: (x['COD_ATO'],x['DESCR']),TJData.to_json(atos_juiz)))
# set_atos_juiz_2 = set(map(lambda x: (x['COD_ATO'],x['DESCR']),TJData.to_json(atos_juiz_2)))
# set_atos_juiz_2.difference(set_atos_juiz)

# %% [raw]
# atos_juiz = TJData.read_csv(TJData.csv['ato_juiz_2'],usecols=['COD_TIP_ATO','COD_ATO','DESCR','COD_TIP_MOV'])
# atos_juiz = atos_juiz.rename(columns=lambda x: x.lower())
# atos_juiz = atos_juiz.rename(columns={'cod_tip_ato':'tipo_ato_juiz','cod_tip_mov':'tipo_movimento'})
# atos_juiz.descr = TJData.to_utf8_bytes(atos_juiz.descr)
# atos_juiz = TJData.to_json(atos_juiz)
# r_post = api.concurrent_request(api.post,'atosjuiz',atos_juiz)

# %% [markdown]
# ### Tipo Documento

# %% [raw]
# tipos_documento = TJData.read_csv(TJData.csv['tipo_documento'],usecols=['ID_TIP_DOC','DESCR'])
# tipos_documento = tipos_documento.rename(columns=lambda x : x.lower())
# tipos_documento.descr = TJData.to_utf8_bytes(tipos_documento.descr)
# tipos_documento = TJData.to_json(tipos_documento)
# r_post = api.concurrent_request(api.post,'tiposdocumento',tipos_documento)

# %% [markdown]
# ### Processo

# %% [markdown]
# #### Obtem as serventias com função de Juizado Especial Cível das comarcas de Bangu e Campo Grande

# %%
serventias_jec = pd.DataFrame(
    list(map(lambda x: (x.comarca.desc_redu,x.comarca.desc_coma, x.cod_serv, x.desc_serv),
        tj.Serventia.objects.filter(
            Q(desc_serv__contains='Juizado Especial Cível'),
            Q(comarca__desc_redu='BAN') | Q(comarca__desc_redu='CGR')
    ))),
    columns=['comarca.desc_redu','comarca.desc_coma','cod_serv','desc_serv']
)
serventias_jec
# Out:
#   comarca.desc_redu         comarca.desc_coma  cod_serv  \
# 0               BAN         Regional de Bangu    204009
# 1               BAN         Regional de Bangu    204509
# 2               BAN         Regional de Bangu    204025
# 3               BAN         Regional de Bangu    204525
# 4               CGR  Regional de Campo Grande    205020
# 5               CGR  Regional de Campo Grande    205520
# 6               CGR  Regional de Campo Grande    205507
# 7               CGR  Regional de Campo Grande    205007
#
#                                 desc_serv
# 0  Cartório do 17º Juizado Especial Cível
# 1              17º Juizado Especial Cível
# 2  Cartório do 29º Juizado Especial Cível
# 3              29º Juizado Especial Cível
# 4  Cartório do 26º Juizado Especial Cível
# 5              26º Juizado Especial Cível
# 6              18º Juizado Especial Cível
# 7  Cartório do 18º Juizado Especial Cível

# %% [markdown]
# #### Obtem a lista de planilhas para processar resultantes codigos de serventias e do intervalo de anos selecinados

# %% [raw]
# # colunas que serão utilizadas no processo
# usecols=['COD_PROC','COD_COMP','COD_SERV','ID_PROC','COD_CLASSE','COD_ASSUNTO','DATA_CAD']
#
# # obtem uma lista com tuplas combinando as serventias e o intervalo de ano desejado
# servs_anos = TJData.build_serventias_anos_list(list(serventias_jec.cod_serv),range(2013,2017))
#
# # obtem a lista de arquivos disponíveis para processar
# files_processo = TJData.list_files_in_serventias_anos(TJData.processo,servs_anos)
# # lista codigos de serventia
# serventias = list(map(lambda x : x,serventias_jec.cod_serv))
# serventias

# %% [raw]
# # le em paralelo os arquivos referentes aos processos
# processo_dfs = TJData.concurrent_read(TJData.clean_processo, files_processo, kwargs = {
#     'usecols':usecols
# })
# # unifica em um unico dataframe
# processo_dfs = pd.concat(processo_dfs)
# # obtem lista de cod_procs existentes no dataframe
# cod_procs = list(processo_dfs.cod_proc.unique())

# %% [raw]
# usecols = ['ID_PROC','COD_CNJ','COD_PROC']
# usecols_ = list(map(lambda x: x.lower(),usecols))
# proc_unico_dfs = []
# for df in TJData.read_csv(TJData.csv['processo_unico'], usecols=usecols, chunksize=3000000):
#     # filtra chunk do dataframe pelos processos listados a partir dos dataframes lidos anteriormente
#     df = df[df.COD_PROC.isin(cod_procs)]
#     df = df.rename(columns=lambda x : x.lower())
#     df.id_proc = df.id_proc.apply(lambda x : str(x))
#     df = df[usecols_]
#     if not df.empty:
#         proc_unico_dfs.append(df)
#
# # unifica dataframes filtrados identificados a partir dos chunk
# proc_unico_dfs = pd.concat(proc_unico_dfs)
# # realiza left join com os codigos cnj identificados
# processo_dfs = processo_dfs.merge(proc_unico_dfs, on=['cod_proc','id_proc'], how='left')
# del proc_unico_dfs
# processo_dfs.cod_proc = TJData.to_utf8_bytes(processo_dfs.cod_proc)
# processo_dfs.cod_cnj = TJData.to_utf8_bytes(processo_dfs.cod_cnj)
# processo_dfs = TJData.to_json(processo_dfs)
# processo_dfs = api.split_list(processo_dfs, 100)
# r_post = api.concurrent_request(api.post,'processos',processo_dfs)
# if r_post:
#     r_retry = retry_post('processos',r_post)

# %% [raw]
# len_proc = []
# for p in processo_dfs:
#     len_proc.append(len(p))
# sum(len_proc),len(processo_dfs),len(processo_dfs[0]),len(processo_dfs[-1])

# %% [markdown]
# ### Andamento Processo (Sentença)

# %% [raw]
# servs_anos = TJData.build_serventias_anos_list(list(serventias_jec.cod_serv),range(2013,2017))
# cod_procs = list(map(lambda x: x.cod_proc,tj.Processo.objects.all()))
# juizes = list(map(lambda x: x.num_matr, tj.Funcionario.objects.all()))
# tipos_andamento = list(map(lambda x: x.cod_tip_and, tj.TipoAndamento.objects.all()))
# usecols = ['COD_PROC','ORDEM','COD_TIP_AND','NUM_MATR_JUIZ','COD_TIP_ATO','DT_ATO','COD_ATO','COD_SERV','COD_TIP_DEC_REC','TXT_DESCR','TXT_DESCR_RES']
# mergecols = ['cod_proc','ordem']
# files_andamentos_clob = TJData.list_files_in_serventias_anos(TJData.andamento_processo_clob,servs_anos)
# files_andamentos = TJData.list_files_in_serventias_anos(TJData.andamento_processo,servs_anos)
# files_andamentos += list(filter(lambda x : re.search(r'AndamentoProcesso_',x),files_andamentos_clob))
# files_andamentos_clob = list(filter(lambda x : re.search(r'AndamentoProcessoClob_',x),files_andamentos_clob))
#
# clean_andamentos_kwargs = {
#     'usecols':usecols,
#     'mergecols':mergecols,
#     'files_clob_list':files_andamentos_clob,
#     'clob_pattern':TJData.andamento_processo_clob,
#     'juizes':juizes,
#     'tipos_andamento':tipos_andamento,
# }

# %% [raw]
# # le em paralelo os arquivos referentes aos processos
# andamento_dfs = TJData.concurrent_read(TJData.clean_andamentos, files_andamentos, clean_andamentos_kwargs)
# andamento_dfs = pd.concat(andamento_dfs)

# %% [raw]
# andamento_dfs = andamento_dfs.sort_values(['processo','ordem','juiz'])
# andamento_dfs = andamento_dfs.drop_duplicates()
# usecols = list(andamento_dfs.columns)
# usecols.remove('num_seq')
# andamento_dfs = andamento_dfs[usecols]
# andamento_dfs = TJData.to_json(andamento_dfs)
# andamento_dfs = api.split_list(andamento_dfs,150)
# and_r_post = api.concurrent_request(api.post,'andamentosprocesso',andamento_dfs)

# %% [raw]
# and_retry_post = [retry_post('andamentosprocesso',post) for post in and_r_post ]

# %% [markdown]
# ### Personagem

# %% [raw]
# files = [TJData.csv['personagem'],TJData.csv['personagem_especial'],TJData.csv['personagem_especial_original'],TJData.csv['personagem_processo']]
# num_lines = [ TJData.count_lines(file) for file in files ]
# num_lines

# %% [raw]
# #obtem a lista de processos cadastrados
# processos_indb = list(map(lambda x : x.cod_proc,tj.Processo.objects.all()))
#
# usecols = ['COD_PROC','COD_PERS','COD_ADV','COD_TIP_PERS','TIP_POLO']
# personagem_processo = pd.DataFrame(columns=usecols).rename(columns=lambda x: x.lower())
# # carrega dados de personagem processo filtrando pelos processos ja cadastrados no banco de dados
# for df in TJData.read_csv(TJData.csv['personagem_processo'], usecols=usecols ,chunksize=1000000):
#     df = df.rename(columns= lambda x : x.lower())
#     df.cod_pers = TJData.nan_to_int(df.cod_pers)
#     df.cod_adv = TJData.nan_to_int(df.cod_adv)
#     df.cod_tip_pers = TJData.nan_to_int(df.cod_tip_pers)
#     df = df[df.cod_proc.isin(processos_indb)]
#     personagem_processo = pd.concat([personagem_processo,df])

# %% [raw]
# # obtem tipos personagem cadastrados
# tp_pers = pd.DataFrame(sorted(api.response_to_json(api.get('tipospersonagem')), key = lambda k:k['cod_tip_pers']))
# # converte para string os codigos do personagem para cruzar com os cod_tip_pers
# tp_pers.cod_tip_pers = TJData.nan_to_int(tp_pers.cod_tip_pers)
# tp_pers.cod_tip_pers_inv = TJData.nan_to_int(tp_pers.cod_tip_pers_inv)
# # filtra os personagem_processo baseado nos processos cadastrados no banco
# tp_pers = tp_pers[tp_pers.cod_tip_pers.isin(list(personagem_processo.cod_tip_pers.unique()))]
# # filtra os personagem_processo caso sejam advogado, escritório advocacia, personagem ativo e passivo
# tp_pers = tp_pers[(tp_pers.cod_tip_pers=='137') | (tp_pers.cod_tip_pers=='0') | (tp_pers.tipo_part=='A') | (tp_pers.tipo_part=='P')].reset_index(drop=True)
# tp_pers = list(tp_pers.cod_tip_pers)
# # filtra personagem_processo pelos tipos selecionados
# personagem_processo = personagem_processo[personagem_processo.cod_tip_pers.isin(tp_pers)].sort_values(by='cod_proc', ascending=True).reset_index(drop=True)

# %% [raw]
# cod_pers = list(personagem_processo[~pd.isna(personagem_processo.cod_pers)].cod_pers.unique())
# cod_advs = list(personagem_processo[~pd.isna(personagem_processo.cod_adv)].cod_adv.unique())

# %% [markdown]
# #### carrega dados codigo e nome do personagem especial (jurídica) e personagens pessoa fĩsicaa

# %% [raw]
# # pessoa jurídica
# usecols = ['COD_PERS','NOME']
# personagem = TJData.read_csv(TJData.csv['personagem_especial_original'], usecols=usecols ,nrows=500)
# personagem = personagem.rename(columns=lambda x: x.lower())
# personagem = personagem[['cod_pers','nome']]
# personagem.cod_pers = TJData.nan_to_int(personagem.cod_pers)
# personagem.nome = TJData.to_utf8_bytes(personagem.nome)
#
# # pessoa física
# for df in TJData.read_csv(TJData.csv['personagem'], usecols=usecols ,chunksize=1000000):
#     df = df.rename(columns= lambda x : x.lower())
#     df = df.rename(columns=lambda x: x.lower())
#     df = df[['cod_pers','nome']]
#     df.cod_pers = TJData.nan_to_int(df.cod_pers)
#     df.nome = TJData.to_utf8_bytes(df.nome)
#     df = df[df.cod_pers.isin(cod_pers)]
#     personagem = pd.concat([personagem,df])
#
# # join com personagens pessoa física e jurídica com processo
# personagem_processo = personagem_processo.merge(personagem, on='cod_pers', how='left')

# %% [markdown]
# #### carrega dados dos advogados

# %% [raw]
# usecols = ['COD_ADV','NUM_OAB','NOME_ADV']
# advogados = TJData.read_csv(TJData.csv['advogado'],usecols=usecols).rename(columns=lambda x: x.lower())
# advogados.num_oab = TJData.to_utf8_bytes(advogados.num_oab)
# advogados.nome_adv = TJData.to_utf8_bytes(advogados.nome_adv)
# advogados.cod_adv = TJData.nan_to_int(advogados.cod_adv)
# # join de advogados com personagem processo
# personagem_processo = personagem_processo.merge(advogados, on='cod_adv', how='left')

# %% [markdown]
# #### divide as associações aos processos entre personagens (fisico ou juridico) e advogados

# %% [raw]
# adv_usecols = ['cod_proc','cod_adv','cod_tip_pers','tip_polo','num_oab','nome_adv']
# pers_usecols = ['cod_proc','cod_pers','cod_tip_pers','tip_polo','nome']
# # obtem associações entre advogados e processos
# advogado_processo = personagem_processo[~pd.isna(personagem_processo.cod_adv)]
# advogado_processo = advogado_processo[adv_usecols]
#
# # obtem associações entre personagens e processos
# personagem_processo = personagem_processo[pd.isna(personagem_processo.cod_adv)]
# personagem_processo = personagem_processo[pers_usecols]
#
# # obtem personagem a partir das associações
# personagem = personagem_processo[['cod_pers','nome']]
# personagem = personagem.drop_duplicates()
#
# # obtem detalhamento das associações entre personagem e processo
# personagem_processo = personagem_processo[['cod_proc','cod_pers','cod_tip_pers']].drop_duplicates()
# personagem_processo = personagem_processo.rename(columns={
#     'cod_proc':'processo',
#     'cod_pers':'personagem',
#     'cod_tip_pers':'tipo_personagem'
# })
#
# # obtem advogados a partir das associações
# advogados = advogado_processo[['cod_adv','num_oab','nome_adv']]
# advogados = advogados.drop_duplicates()
# advogados = advogados[~(pd.isna(advogados.nome_adv)) | ~(pd.isna(advogados.num_oab))]
#
# # obtem detalhamento das associações entre advogados e processo
# advogado_processo = advogado_processo[['cod_proc','cod_adv','cod_tip_pers','tip_polo']].drop_duplicates()
# advogado_processo = advogado_processo.rename(columns={
#     'cod_proc':'processo',
#     'cod_adv':'advogado',
#     'cod_tip_pers':'tipo_personagem'
# })

# %% [raw]
# advogados = TJData.to_json(advogados)
# personagem = TJData.to_json(personagem)
# advogado_processo = TJData.to_json(advogado_processo)
# personagem_processo = TJData.to_json(personagem_processo)

# %% [raw]
# advogados = api.split_list(advogados,100)
# personagem = api.split_list(personagem,100)
# advogado_processo = api.split_list(advogado_processo,100)
# personagem_processo = api.split_list(personagem_processo,100)

# %% [raw]
# post_adv = api.concurrent_request(api.post,'advogados',advogados)
# if post_adv:
#     retry_post_adv = retry_post('advogados',post_adv)
#
# post_pers = api.concurrent_request(api.post,'personagens',personagem)
# if post_pers:
#     retry_post_pers = retry_post('personagens',post_pers)
#
# post_adv_proc = api.concurrent_request(api.post,'advogadosprocesso',advogado_processo)
# if post_adv_proc:
#     retry_post_adv_proc = retry_post('advogadosprocesso',post_adv_proc)
#
# post_pers_proc = api.concurrent_request(api.post,'personagensprocesso',personagem_processo)
# if post_pers_proc:
#     retry_post_pers_proc = retry_post('personagensprocesso',post_pers_proc)

# %% [markdown]
# ### Documentos (Iniciais e Contestação)

# %% [raw]
# usecols=['PROC__COD_PROC','PROCOORPTIPDOC__ID_TIP_DOC','PDVP__COD_DOCTO_ELET','PROC__COD_ASSUNTO','PROC__COD_CLASSE','PROC__COD_COMP']
# docs = pd.concat([TJData.read_csv(TJData.csv['iniciais'],usecols=usecols),TJData.read_csv(TJData.csv['contestacoes'],usecols=usecols)])
# docs = docs.rename(columns={
#     'PROC__COD_PROC':'processo',
#     'PROC__COD_COMP':'competencia',
#     'PROC__COD_ASSUNTO':'assunto',
#     'PROC__COD_CLASSE':'classe',
#     'PDVP__COD_DOCTO_ELET':'cod_docto_elet',
#     'PROCOORPTIPDOC__ID_TIP_DOC':'tipo_documento'
# })
# docs.processo = TJData.to_utf8(docs.processo)
# docs.cod_docto_elet = TJData.to_utf8(docs.cod_docto_elet)
# docs.competencia = docs.competencia.astype(int)
# docs.assunto = docs.assunto.astype(int)
# docs.classe = docs.classe.astype(int)
# docs = TJData.to_json(docs)
# docs = api.split_list(docs,100)
# docs_post = api.concurrent_request(api.post,'documentosprocesso',docs)
# if docs_post:
#     retry_docs_post = retry_post('documentosprocesso',docs_post)

# %% [markdown]
# ### Arquivos similaridade

# %% [raw]
# ### investigando arquivos antigos
# # obtem lista de diretorios base desejados
# base_similar_dirs = [ os.path.join(dir_ref[0],dir_ref[1]) for dir_ref in list(itertools.product(['/tj_files/civil_legal_analisys'], ['tjrj','master','fraude','tjrj2'])) ]
# # lista conteudo de cada diretorio base
# base_similar_dirs = [ list(itertools.product([base_similar_dir], os.listdir(base_similar_dir))) for base_similar_dir in base_similar_dirs ]
# # obtem paths absolutos
# base_similar_dirs = list(map(lambda similar_dirs_tuples_list: list(map(lambda x: os.path.join(x[0],x[1]) ,similar_dirs_tuples_list)) ,base_similar_dirs))
# # unifica lista de listas
# base_similar_dirs = list(itertools.chain.from_iterable(base_similar_dirs))
# # filtra diretorios desejados
# base_similar_dirs = list(filter(lambda x: re.search(r'civil_legal_analisys/(tjrj|master|fraude|tjrj2)/(similar_|similares_)',x), base_similar_dirs))
# # mapeia path dos arquivos
# similar_files = list(map(lambda similar_dir: os.listdir(similar_dir) , base_similar_dirs))
# similar_files = list(itertools.chain.from_iterable([ list(itertools.product([dir_files[0]],dir_files[1])) for dir_files in list(zip(base_similar_dirs,similar_files))]))
# similar_files = list(map(lambda x: os.path.join(x[0],x[1]).replace('/tj_files/',''),similar_files))
#
# # os arquivos eram utilizados para carregar os detalhes dos processos

# %% [raw]
# similars = TJData.read_csv('civil_legal_analisys/tjrj2/processos_similares.csv')
# processos_indb = list(map(lambda x: x.cod_proc ,tj.Processo.objects.all()))
# similars = similars[(similars.COD_PROCESSO_A.isin(processos_indb)&(similars.COD_PROCESSO_B.isin(processos_indb)))]
# similars.SIMILARIDADE = similars.SIMILARIDADE.apply(lambda x: float(x.strip('%')))
# similars = similars[['COD_PROCESSO_A','COD_PROCESSO_B','SIMILARIDADE']].rename(columns={
#     'COD_PROCESSO_A':'processo_base','COD_PROCESSO_B':'processo_similar','SIMILARIDADE':'similaridade'
# })
# similars = TJData.to_json(similars)
# similars = api.split_list(similars, 100)
# post_similars = api.concurrent_request(api.post,'processossimilares',similars)
# if post_similars:
#     retry_post_similars = retry_post('processossimilares',post_similars)

# %% [raw]
# post_similars = list(map(lambda post: json.loads(post.request.body) ,post_similars))
# post_similars = api.concurrent_request(api.post,'processossimilares',post_similars)

# %% [markdown]
# ### zona de teste

# %% [raw]
# from frontend import serializers, models
# advogados = serializers.AdvogadoDisponivelSerializer(models.AdvogadoDisponivel.objects.all(),many=True)
# serventias = serializers.ServentiaDisponivelSerializer(models.ServentiaDisponivel.objects.all(),many=True)
# comarcas = serializers.ComarcaDisponivelSerializer(models.ComarcasDisponivel.objects.all(),many=True)
# personagens = serializers.PersonagemDisponivelSerializer(models.PersonagemDisponivel.objects.all(),many=True)
# juizes = serializers.JuizDisponivelSerializer(models.JuizDisponivel.objects.all(),many=True)
# anos = serializers.AnoDisponivelSerializer(models.AnoDisponivel.objects.all(),many=True)
# assuntos = serializers.AssuntoDiponivelSerializer(models.AssuntoDisponivel.objects.all(),many=True)
# classes = serializers.ClasseDisponivelSerializer(models.ClasseDisponivel.objects.all(),many=True)

# %% [raw]
# a = json.loads(json.dumps({
#     'advogados' : advogados.data,
#     'serventias': serventias.data,
#     'comarcas':comarcas.data,
#     'personagens':personagens.data,
#     'juizes':juizes.data,
#     'anos':anos.data,
#     'assuntos':assuntos.data,
#     'classes':classes.data
# }))

# %%
from frontend import models, serializers

# %%
serializers.ComarcaServentiaDisponivelSerializer(models.ComarcaServentiaDisponivel.objects.all(),many=True)
# Out:
# ComarcaServentiaDisponivelSerializer(<QuerySet [<ComarcaServentiaDisponivel: Cartório do 17º Juizado Especial Cível - Regional de Bangu>, <ComarcaServentiaDisponivel: Cartório do 29º Juizado Especial Cível - Regional de Bangu>, <ComarcaServentiaDisponivel: Cartório do 18º Juizado Especial Cível - Regional de Campo Grande>, <ComarcaServentiaDisponivel: Cartório do 26º Juizado Especial Cível - Regional de Campo Grande>]>, many=True):
#     id = IntegerField(label='ID', read_only=True)
#     serventia = CharField(style={'base_template': 'textarea.html'})
#     comarca = CharField(style={'base_template': 'textarea.html'})

# %%
#api.response_to_json(api.get('classesassuntosdisponiveis','?assunto=indenização'))
api.resources
# Out:
# {'users': 'http://0.0.0.0:8000/api/models/users/',
#  'assuntos': 'http://0.0.0.0:8000/api/models/assuntos/',
#  'classes': 'http://0.0.0.0:8000/api/models/classes/',
#  'comarcas': 'http://0.0.0.0:8000/api/models/comarcas/',
#  'competencias': 'http://0.0.0.0:8000/api/models/competencias/',
#  'serventias': 'http://0.0.0.0:8000/api/models/serventias/',
#  'classesassuntos': 'http://0.0.0.0:8000/api/models/classesassuntos/',
#  'processos': 'http://0.0.0.0:8000/api/models/processos/',
#  'tipospersonagem': 'http://0.0.0.0:8000/api/models/tipospersonagem/',
#  'tiposmovimento': 'http://0.0.0.0:8000/api/models/tiposmovimento/',
#  'tiposandamento': 'http://0.0.0.0:8000/api/models/tiposandamento/',
#  'cargos': 'http://0.0.0.0:8000/api/models/cargos/',
#  'funcionarios': 'http://0.0.0.0:8000/api/models/funcionarios/',
#  'tiposdecisaorecurso': 'http://0.0.0.0:8000/api/models/tiposdecisaorecurso/',
#  'tiposatojuiz': 'http://0.0.0.0:8000/api/models/tiposatojuiz/',
#  'atosjuiz': 'http://0.0.0.0:8000/api/models/atosjuiz/',
#  'tiposdocumento': 'http://0.0.0.0:8000/api/models/tiposdocumento/',
#  'andamentosprocesso': 'http://0.0.0.0:8000/api/models/andamentosprocesso/',
#  'personagens': 'http://0.0.0.0:8000/api/models/personagens/',
#  'advogados': 'http://0.0.0.0:8000/api/models/advogados/',
#  'personagensprocesso': 'http://0.0.0.0:8000/api/models/personagensprocesso/',
#  'advogadosprocesso': 'http://0.0.0.0:8000/api/models/advogadosprocesso/',
#  'documentosprocesso': 'http://0.0.0.0:8000/api/models/documentosprocesso/',
#  'processossimilares': 'http://0.0.0.0:8000/api/models/processossimilares/',
#  'processossimilaresreport': 'http://0.0.0.0:8000/api/models/processossimilaresreport/',
#  'avaliacoes': 'http://0.0.0.0:8000/api/models/avaliacoes/',
#  'gruposimilares': 'http://0.0.0.0:8000/api/models/gruposimilares/',
#  'usuariosgruposimilares': 'http://0.0.0.0:8000/api/models/usuariosgruposimilares/',
#  'processosgruposimilares': 'http://0.0.0.0:8000/api/models/processosgruposimilares/',
#  'anosdisponiveis': 'http://0.0.0.0:8000/api/models/anosdisponiveis/',
#  'comarcasserventiasdisponiveis': 'http://0.0.0.0:8000/api/models/comarcasserventiasdisponiveis/',
#  'classesassuntosdisponiveis': 'http://0.0.0.0:8000/api/models/classesassuntosdisponiveis/',
#  'personagensdisponiveis': 'http://0.0.0.0:8000/api/models/personagensdisponiveis/',
#  'juizessdisponiveis': 'http://0.0.0.0:8000/api/models/juizessdisponiveis/',
#  'advogadossdisponiveis': 'http://0.0.0.0:8000/api/models/advogadossdisponiveis/'}

# %%
api.response_to_json(api.get('personagensdisponiveis','?personagem=2na info'))
# Out:
# [{'id': '478314', 'nome_personagem': '2NA INFORMATICA E TERINAMENTO S/C LTDA'},
#  {'id': '539763', 'nome_personagem': '2NA INFORMÁTICA E TREINAMENTO'},
#  {'id': '532838',
#   'nome_personagem': '2NA INFORMATICA E TREINAMENTO LTDA (SOS COMPUTADORES)'},
#  {'id': '669413', 'nome_personagem': '2NA INFORMATICA E TREINAMENTO S/C LTDA'},
#  {'id': '352640', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO'},
#  {'id': '531177', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO'},
#  {'id': '561687', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO'},
#  {'id': '651623', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO'},
#  {'id': '347667', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '364788', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '381517', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '381575', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '381611', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '398799', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '398912', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '416712', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '420272', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '425845', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '433995', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '451587', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '469619', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '485162', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '487348', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '504525', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '504532', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '522229', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '531179', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '540463', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '558367', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '558413', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '579017', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '592962', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '593164', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '602147', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '619082', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '646631', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA'},
#  {'id': '485231', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA,'},
#  {'id': '499095', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA,'},
#  {'id': '522273', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA,'},
#  {'id': '540462', 'nome_personagem': '2NA INFORMÁTICA TREINAMENTO S/C LTDA,'},
#  {'id': '598810',
#   'nome_personagem': 'S.O.S COMPUTADORES DE BANGU (2NA INFO E TREINAMENTO LTDA)'}]

# %%
api.resources
# Out:
# {'users': 'http://0.0.0.0:8000/api/models/users/',
#  'assuntos': 'http://0.0.0.0:8000/api/models/assuntos/',
#  'classes': 'http://0.0.0.0:8000/api/models/classes/',
#  'comarcas': 'http://0.0.0.0:8000/api/models/comarcas/',
#  'competencias': 'http://0.0.0.0:8000/api/models/competencias/',
#  'serventias': 'http://0.0.0.0:8000/api/models/serventias/',
#  'classesassuntos': 'http://0.0.0.0:8000/api/models/classesassuntos/',
#  'processos': 'http://0.0.0.0:8000/api/models/processos/',
#  'tipospersonagem': 'http://0.0.0.0:8000/api/models/tipospersonagem/',
#  'tiposmovimento': 'http://0.0.0.0:8000/api/models/tiposmovimento/',
#  'tiposandamento': 'http://0.0.0.0:8000/api/models/tiposandamento/',
#  'cargos': 'http://0.0.0.0:8000/api/models/cargos/',
#  'funcionarios': 'http://0.0.0.0:8000/api/models/funcionarios/',
#  'tiposdecisaorecurso': 'http://0.0.0.0:8000/api/models/tiposdecisaorecurso/',
#  'tiposatojuiz': 'http://0.0.0.0:8000/api/models/tiposatojuiz/',
#  'atosjuiz': 'http://0.0.0.0:8000/api/models/atosjuiz/',
#  'tiposdocumento': 'http://0.0.0.0:8000/api/models/tiposdocumento/',
#  'andamentosprocesso': 'http://0.0.0.0:8000/api/models/andamentosprocesso/',
#  'personagens': 'http://0.0.0.0:8000/api/models/personagens/',
#  'advogados': 'http://0.0.0.0:8000/api/models/advogados/',
#  'personagensprocesso': 'http://0.0.0.0:8000/api/models/personagensprocesso/',
#  'advogadosprocesso': 'http://0.0.0.0:8000/api/models/advogadosprocesso/',
#  'documentosprocesso': 'http://0.0.0.0:8000/api/models/documentosprocesso/',
#  'processossimilares': 'http://0.0.0.0:8000/api/models/processossimilares/',
#  'processossimilaresreport': 'http://0.0.0.0:8000/api/models/processossimilaresreport/',
#  'avaliacoes': 'http://0.0.0.0:8000/api/models/avaliacoes/',
#  'gruposimilares': 'http://0.0.0.0:8000/api/models/gruposimilares/',
#  'usuariosgruposimilares': 'http://0.0.0.0:8000/api/models/usuariosgruposimilares/',
#  'processosgruposimilares': 'http://0.0.0.0:8000/api/models/processosgruposimilares/',
#  'anosdisponiveis': 'http://0.0.0.0:8000/api/models/anosdisponiveis/',
#  'comarcasserventiasdisponiveis': 'http://0.0.0.0:8000/api/models/comarcasserventiasdisponiveis/',
#  'classesassuntosdisponiveis': 'http://0.0.0.0:8000/api/models/classesassuntosdisponiveis/',
#  'personagensdisponiveis': 'http://0.0.0.0:8000/api/models/personagensdisponiveis/',
#  'juizessdisponiveis': 'http://0.0.0.0:8000/api/models/juizessdisponiveis/',
#  'advogadossdisponiveis': 'http://0.0.0.0:8000/api/models/advogadossdisponiveis/'}

# %%
from django.db.models import Q

# %%
a = n2na[0]

# %%
api.resources
# Out:
# {'users': 'http://0.0.0.0:8000/api/models/users/',
#  'assuntos': 'http://0.0.0.0:8000/api/models/assuntos/',
#  'classes': 'http://0.0.0.0:8000/api/models/classes/',
#  'comarcas': 'http://0.0.0.0:8000/api/models/comarcas/',
#  'competencias': 'http://0.0.0.0:8000/api/models/competencias/',
#  'serventias': 'http://0.0.0.0:8000/api/models/serventias/',
#  'classesassuntos': 'http://0.0.0.0:8000/api/models/classesassuntos/',
#  'processos': 'http://0.0.0.0:8000/api/models/processos/',
#  'tipospersonagem': 'http://0.0.0.0:8000/api/models/tipospersonagem/',
#  'tiposmovimento': 'http://0.0.0.0:8000/api/models/tiposmovimento/',
#  'tiposandamento': 'http://0.0.0.0:8000/api/models/tiposandamento/',
#  'cargos': 'http://0.0.0.0:8000/api/models/cargos/',
#  'funcionarios': 'http://0.0.0.0:8000/api/models/funcionarios/',
#  'tiposdecisaorecurso': 'http://0.0.0.0:8000/api/models/tiposdecisaorecurso/',
#  'tiposatojuiz': 'http://0.0.0.0:8000/api/models/tiposatojuiz/',
#  'atosjuiz': 'http://0.0.0.0:8000/api/models/atosjuiz/',
#  'tiposdocumento': 'http://0.0.0.0:8000/api/models/tiposdocumento/',
#  'andamentosprocesso': 'http://0.0.0.0:8000/api/models/andamentosprocesso/',
#  'personagens': 'http://0.0.0.0:8000/api/models/personagens/',
#  'advogados': 'http://0.0.0.0:8000/api/models/advogados/',
#  'personagensprocesso': 'http://0.0.0.0:8000/api/models/personagensprocesso/',
#  'advogadosprocesso': 'http://0.0.0.0:8000/api/models/advogadosprocesso/',
#  'documentosprocesso': 'http://0.0.0.0:8000/api/models/documentosprocesso/',
#  'processossimilares': 'http://0.0.0.0:8000/api/models/processossimilares/',
#  'processossimilaresreport': 'http://0.0.0.0:8000/api/models/processossimilaresreport/',
#  'avaliacoes': 'http://0.0.0.0:8000/api/models/avaliacoes/',
#  'gruposimilares': 'http://0.0.0.0:8000/api/models/gruposimilares/',
#  'usuariosgruposimilares': 'http://0.0.0.0:8000/api/models/usuariosgruposimilares/',
#  'processosgruposimilares': 'http://0.0.0.0:8000/api/models/processosgruposimilares/',
#  'anosdisponiveis': 'http://0.0.0.0:8000/api/models/anosdisponiveis/',
#  'comarcasserventiasdisponiveis': 'http://0.0.0.0:8000/api/models/comarcasserventiasdisponiveis/',
#  'classesassuntosdisponiveis': 'http://0.0.0.0:8000/api/models/classesassuntosdisponiveis/',
#  'personagensdisponiveis': 'http://0.0.0.0:8000/api/models/personagensdisponiveis/',
#  'juizessdisponiveis': 'http://0.0.0.0:8000/api/models/juizessdisponiveis/',
#  'advogadossdisponiveis': 'http://0.0.0.0:8000/api/models/advogadossdisponiveis/'}

# %%
api.response_to_json(api.get('processossimilaresreport','?page=1'))
# Out:
# {'count': 693293,
#  'next': 'http://0.0.0.0:8000/api/models/processossimilaresreport/?page=2',
#  'previous': None,
#  'results': [{'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1562077/',
#    'similaridade': 98.0,
#    'processo_base_tj': '2016.205.056459-8',
#    'processo_base_cnj': '0056437-67.2016.8.19.0205',
#    'processo_similar_tj': '2016.204.038735-7',
#    'processo_similar_cnj': '0039489-53.2016.8.19.0204',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_base_assunto': 'Antecipação de Tutela / Tutela Específica',
#    'processo_similar_assunto': 'Protesto Indevido de Título',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'RAQUEL CORREA CAMPOS, SHOPFATO',
#    'processo_similar_personagens': 'BANCO DO BRASIL, CROSLEY JOSEPH DE OLIVEIRA ¿ MICROEMPREENDEDOR INDIVIDUAL, MEGAFORT DISTRIBUIDORA IMPORTAÇÃO E EXPORTAÇÃO LTDA',
#    'processo_base_advogados': 'LUCIANO DA SILVA CORRÊA',
#    'processo_similar_advogados': 'GERALDO ROBERTO GOMES, RAFAEL SGANZERLA DURAND, THIAGO ARAÚJO PURIFICAÇÃO',
#    'processo_base_juizes': 'Renata Guarino Martins',
#    'processo_similar_juizes': 'Isabela Lobão dos Santos, Juliana de Mattos Braga'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1562036/',
#    'similaridade': 97.57,
#    'processo_base_tj': '2015.205.048555-6',
#    'processo_base_cnj': '0049006-16.2015.8.19.0205',
#    'processo_similar_tj': '2016.204.004382-6',
#    'processo_similar_cnj': '0004390-22.2016.8.19.0204',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_similar_assunto': 'Rescisão do contrato e devolução do dinheiro',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'FABIANO BITTENCOURT BORGES, RIO DECOR PROMOÇÕES E EVENTOS S/A WEST SHOPPING, WALD MÓVEIS (ARTE EM MADEIRAS)',
#    'processo_similar_personagens': 'IRAN MELO CAMPOS, KPG COMERCIO DE EQUIPAMENTO PARA GASES LTDA (DEL GAS)',
#    'processo_base_advogados': 'ASER SILVA DE OLIVEIRA, CAROLINE MIRANDA DE OLIVEIRA GRUND, HENRIQUE SAMPAIO FERREIRA, LUCIANA ALVES DE SOUZA',
#    'processo_similar_advogados': 'ERIC BARROS XAVIER, HENRIQUE SAMPAIO FERREIRA, WANDIR BRASIL DE LIMA',
#    'processo_base_juizes': 'Joana Elena Dornas, Renata Guarino Martins',
#    'processo_similar_juizes': 'Alexandre Jose da Silva Barbosa, Paloma Bispo dos Santos'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1562114/',
#    'similaridade': 97.57,
#    'processo_base_tj': '2016.204.004382-6',
#    'processo_base_cnj': '0004390-22.2016.8.19.0204',
#    'processo_similar_tj': '2015.205.048555-6',
#    'processo_similar_cnj': '0049006-16.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_base_assunto': 'Rescisão do contrato e devolução do dinheiro',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'IRAN MELO CAMPOS, KPG COMERCIO DE EQUIPAMENTO PARA GASES LTDA (DEL GAS)',
#    'processo_similar_personagens': 'FABIANO BITTENCOURT BORGES, RIO DECOR PROMOÇÕES E EVENTOS S/A WEST SHOPPING, WALD MÓVEIS (ARTE EM MADEIRAS)',
#    'processo_base_advogados': 'ERIC BARROS XAVIER, HENRIQUE SAMPAIO FERREIRA, WANDIR BRASIL DE LIMA',
#    'processo_similar_advogados': 'ASER SILVA DE OLIVEIRA, CAROLINE MIRANDA DE OLIVEIRA GRUND, HENRIQUE SAMPAIO FERREIRA, LUCIANA ALVES DE SOUZA',
#    'processo_base_juizes': 'Alexandre Jose da Silva Barbosa, Paloma Bispo dos Santos',
#    'processo_similar_juizes': 'Joana Elena Dornas, Renata Guarino Martins'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1597068/',
#    'similaridade': 95.54,
#    'processo_base_tj': '2016.204.035328-1',
#    'processo_base_cnj': '0035811-30.2016.8.19.0204',
#    'processo_similar_tj': '2016.205.016006-2',
#    'processo_similar_cnj': '0016123-79.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Antecipação de Tutela / Tutela Específica',
#    'processo_similar_assunto': 'Inclusão Indevida em Cadastro de Inadimplentes',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'EVANILZA PEREIRA VELOSO, QBE BRASIL SEGUROS S/A',
#    'processo_similar_personagens': 'F.AB. ZONA OESTE S.A, MARIA MESQUITA SOARES',
#    'processo_base_advogados': 'ANDRE LUIZ DO RÊGO MONTEIRO TAVARES PEREIRA, MARILDA PIMENTEL DA SILVA',
#    'processo_similar_advogados': 'ADRIANO MOTA CASSOL, ADRIENE RODRIGUES VON RANDOW',
#    'processo_base_juizes': 'Daniela Reetz de Paiva',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte, Marcelo de Oliveira Hemerly'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1562020/',
#    'similaridade': 95.54,
#    'processo_base_tj': '2016.205.016006-2',
#    'processo_base_cnj': '0016123-79.2016.8.19.0205',
#    'processo_similar_tj': '2016.204.035328-1',
#    'processo_similar_cnj': '0035811-30.2016.8.19.0204',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_base_assunto': 'Inclusão Indevida em Cadastro de Inadimplentes',
#    'processo_similar_assunto': 'Antecipação de Tutela / Tutela Específica',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'F.AB. ZONA OESTE S.A, MARIA MESQUITA SOARES',
#    'processo_similar_personagens': 'EVANILZA PEREIRA VELOSO, QBE BRASIL SEGUROS S/A',
#    'processo_base_advogados': 'ADRIANO MOTA CASSOL, ADRIENE RODRIGUES VON RANDOW',
#    'processo_similar_advogados': 'ANDRE LUIZ DO RÊGO MONTEIRO TAVARES PEREIRA, MARILDA PIMENTEL DA SILVA',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte, Marcelo de Oliveira Hemerly',
#    'processo_similar_juizes': 'Daniela Reetz de Paiva'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1562093/',
#    'similaridade': 95.49,
#    'processo_base_tj': '2015.204.025283-8',
#    'processo_base_cnj': '0025416-13.2015.8.19.0204',
#    'processo_similar_tj': '2016.205.013617-5',
#    'processo_similar_cnj': '0013688-35.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização por Dano Material',
#    'processo_similar_assunto': 'Antecipação de Tutela / Tutela Específica',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'CLARO S.A, MARIVALDO DA SILVA NERY',
#    'processo_similar_personagens': 'CLARO S.A, IVANILDO DE SOUSA BREVES',
#    'processo_base_advogados': 'MARCELO NEUMANN MOREIRAS PESSOA, SINOVAL ANACLETO DA SILVA',
#    'processo_similar_advogados': 'EDIVALDO DE SOUZA, EDSON ALVES SILVA JUNIOR, JORGE DOS SANTOS FERREIRA, MARCELO NEUMANN MOREIRAS PESSOA, PATRÍCIA SHIMA',
#    'processo_base_juizes': 'Cristiane Teles Moura Marques, Karen Marinho Rodrigues',
#    'processo_similar_juizes': 'Renata Guarino Martins, Samyra Remzetti Bernardi'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1597025/',
#    'similaridade': 95.49,
#    'processo_base_tj': '2016.205.013617-5',
#    'processo_base_cnj': '0013688-35.2016.8.19.0205',
#    'processo_similar_tj': '2015.204.025283-8',
#    'processo_similar_cnj': '0025416-13.2015.8.19.0204',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_base_assunto': 'Antecipação de Tutela / Tutela Específica',
#    'processo_similar_assunto': 'Indenização por Dano Material',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'CLARO S.A, IVANILDO DE SOUSA BREVES',
#    'processo_similar_personagens': 'CLARO S.A, MARIVALDO DA SILVA NERY',
#    'processo_base_advogados': 'EDIVALDO DE SOUZA, EDSON ALVES SILVA JUNIOR, JORGE DOS SANTOS FERREIRA, MARCELO NEUMANN MOREIRAS PESSOA, PATRÍCIA SHIMA',
#    'processo_similar_advogados': 'MARCELO NEUMANN MOREIRAS PESSOA, SINOVAL ANACLETO DA SILVA',
#    'processo_base_juizes': 'Renata Guarino Martins, Samyra Remzetti Bernardi',
#    'processo_similar_juizes': 'Cristiane Teles Moura Marques, Karen Marinho Rodrigues'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1596685/',
#    'similaridade': 95.26,
#    'processo_base_tj': '2016.204.035328-1',
#    'processo_base_cnj': '0035811-30.2016.8.19.0204',
#    'processo_similar_tj': '2016.204.005638-9',
#    'processo_similar_cnj': '0005653-89.2016.8.19.0204',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_base_assunto': 'Antecipação de Tutela / Tutela Específica',
#    'processo_similar_assunto': 'Declaração de Inexistência de Débito e / Ou da Relação Jurídica',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'EVANILZA PEREIRA VELOSO, QBE BRASIL SEGUROS S/A',
#    'processo_similar_personagens': 'DANIEL REIS VIEIRA, FOZ ÁGUAS 5 - FAB ZONA OESTE S.A.',
#    'processo_base_advogados': 'ANDRE LUIZ DO RÊGO MONTEIRO TAVARES PEREIRA, MARILDA PIMENTEL DA SILVA',
#    'processo_similar_advogados': 'ADRIANO MOTA CASSOL, RENATA NUNES MIRANDA',
#    'processo_base_juizes': 'Daniela Reetz de Paiva',
#    'processo_similar_juizes': 'Cristiane Teles Moura Marques, Jefferson Albernaz Ferreira Ferraz'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1632317/',
#    'similaridade': 95.26,
#    'processo_base_tj': '2016.204.005638-9',
#    'processo_base_cnj': '0005653-89.2016.8.19.0204',
#    'processo_similar_tj': '2016.204.035328-1',
#    'processo_similar_cnj': '0035811-30.2016.8.19.0204',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_base_assunto': 'Declaração de Inexistência de Débito e / Ou da Relação Jurídica',
#    'processo_similar_assunto': 'Antecipação de Tutela / Tutela Específica',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'DANIEL REIS VIEIRA, FOZ ÁGUAS 5 - FAB ZONA OESTE S.A.',
#    'processo_similar_personagens': 'EVANILZA PEREIRA VELOSO, QBE BRASIL SEGUROS S/A',
#    'processo_base_advogados': 'ADRIANO MOTA CASSOL, RENATA NUNES MIRANDA',
#    'processo_similar_advogados': 'ANDRE LUIZ DO RÊGO MONTEIRO TAVARES PEREIRA, MARILDA PIMENTEL DA SILVA',
#    'processo_base_juizes': 'Cristiane Teles Moura Marques, Jefferson Albernaz Ferreira Ferraz',
#    'processo_similar_juizes': 'Daniela Reetz de Paiva'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1596921/',
#    'similaridade': 95.04,
#    'processo_base_tj': '2016.204.007022-2',
#    'processo_base_cnj': '0007040-42.2016.8.19.0204',
#    'processo_similar_tj': '2015.204.025283-8',
#    'processo_similar_cnj': '0025416-13.2015.8.19.0204',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_base_assunto': 'Antecipação de Tutela / Tutela Específica',
#    'processo_similar_assunto': 'Indenização por Dano Material',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'ALDARA MARIA ASSIS DE SOUZA, CLARO S.A',
#    'processo_similar_personagens': 'CLARO S.A, MARIVALDO DA SILVA NERY',
#    'processo_base_advogados': 'MARCELO NEUMANN MOREIRAS PESSOA, PATRÍCIA SHIMA, PRISCILLA MEIRELES MELO',
#    'processo_similar_advogados': 'MARCELO NEUMANN MOREIRAS PESSOA, SINOVAL ANACLETO DA SILVA',
#    'processo_base_juizes': 'Isabela Lobão dos Santos',
#    'processo_similar_juizes': 'Cristiane Teles Moura Marques, Karen Marinho Rodrigues'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1597105/',
#    'similaridade': 94.96,
#    'processo_base_tj': '2015.204.010212-9',
#    'processo_base_cnj': '0010261-67.2015.8.19.0204',
#    'processo_similar_tj': '2016.204.038735-7',
#    'processo_similar_cnj': '0039489-53.2016.8.19.0204',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_similar_assunto': 'Protesto Indevido de Título',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'MARCOS FILIPE DA SILVA ALVES, ULTRAFARMA SAÚDE LTDA',
#    'processo_similar_personagens': 'BANCO DO BRASIL, CROSLEY JOSEPH DE OLIVEIRA ¿ MICROEMPREENDEDOR INDIVIDUAL, MEGAFORT DISTRIBUIDORA IMPORTAÇÃO E EXPORTAÇÃO LTDA',
#    'processo_base_advogados': 'IVANISE DE MELLO LUIZ',
#    'processo_similar_advogados': 'GERALDO ROBERTO GOMES, RAFAEL SGANZERLA DURAND, THIAGO ARAÚJO PURIFICAÇÃO',
#    'processo_base_juizes': 'Ana Quezia Pereira de Freitas, Isabela Lobão dos Santos',
#    'processo_similar_juizes': 'Isabela Lobão dos Santos, Juliana de Mattos Braga'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1632354/',
#    'similaridade': 94.96,
#    'processo_base_tj': '2016.204.038735-7',
#    'processo_base_cnj': '0039489-53.2016.8.19.0204',
#    'processo_similar_tj': '2015.204.010212-9',
#    'processo_similar_cnj': '0010261-67.2015.8.19.0204',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_base_assunto': 'Protesto Indevido de Título',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'BANCO DO BRASIL, CROSLEY JOSEPH DE OLIVEIRA ¿ MICROEMPREENDEDOR INDIVIDUAL, MEGAFORT DISTRIBUIDORA IMPORTAÇÃO E EXPORTAÇÃO LTDA',
#    'processo_similar_personagens': 'MARCOS FILIPE DA SILVA ALVES, ULTRAFARMA SAÚDE LTDA',
#    'processo_base_advogados': 'GERALDO ROBERTO GOMES, RAFAEL SGANZERLA DURAND, THIAGO ARAÚJO PURIFICAÇÃO',
#    'processo_similar_advogados': 'IVANISE DE MELLO LUIZ',
#    'processo_base_juizes': 'Isabela Lobão dos Santos, Juliana de Mattos Braga',
#    'processo_similar_juizes': 'Ana Quezia Pereira de Freitas, Isabela Lobão dos Santos'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1667637/',
#    'similaridade': 94.95,
#    'processo_base_tj': '2016.204.007022-2',
#    'processo_base_cnj': '0007040-42.2016.8.19.0204',
#    'processo_similar_tj': '2016.205.013617-5',
#    'processo_similar_cnj': '0013688-35.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_base_assunto': 'Antecipação de Tutela / Tutela Específica',
#    'processo_similar_assunto': 'Antecipação de Tutela / Tutela Específica',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'ALDARA MARIA ASSIS DE SOUZA, CLARO S.A',
#    'processo_similar_personagens': 'CLARO S.A, IVANILDO DE SOUSA BREVES',
#    'processo_base_advogados': 'MARCELO NEUMANN MOREIRAS PESSOA, PATRÍCIA SHIMA, PRISCILLA MEIRELES MELO',
#    'processo_similar_advogados': 'EDIVALDO DE SOUZA, EDSON ALVES SILVA JUNIOR, JORGE DOS SANTOS FERREIRA, MARCELO NEUMANN MOREIRAS PESSOA, PATRÍCIA SHIMA',
#    'processo_base_juizes': 'Isabela Lobão dos Santos',
#    'processo_similar_juizes': 'Renata Guarino Martins, Samyra Remzetti Bernardi'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1632221/',
#    'similaridade': 94.72,
#    'processo_base_tj': '2016.205.011584-6',
#    'processo_base_cnj': '0011602-91.2016.8.19.0205',
#    'processo_similar_tj': '2016.204.014204-0',
#    'processo_similar_cnj': '0014255-69.2016.8.19.0204',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_similar_assunto': 'Cobrança de Quantia Indevida',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'MIRIAM CARVALHO DE ANDRADE DA SILVA, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_similar_personagens': 'FABRICIA LIRA GONÇALVES, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_base_advogados': 'CARLOS MARTINS DE OLIVEIRA, JEFFERSON FRANKLIN BATISTA DA SILVA',
#    'processo_similar_advogados': 'ALEXANDRE GAMEIRO DE BRITO, CARLOS MARTINS DE OLIVEIRA, JULIO CEZAR COELHO FERRAZ, MARCUS VINICIUS FREITAS DA SILVA',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte, Marcelo de Oliveira Hemerly',
#    'processo_similar_juizes': 'Daniela Reetz de Paiva, Karen Marinho Rodrigues, Monique Abreu David'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1631350/',
#    'similaridade': 94.72,
#    'processo_base_tj': '2016.204.014204-0',
#    'processo_base_cnj': '0014255-69.2016.8.19.0204',
#    'processo_similar_tj': '2016.205.011584-6',
#    'processo_similar_cnj': '0011602-91.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Cobrança de Quantia Indevida',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'FABRICIA LIRA GONÇALVES, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_similar_personagens': 'MIRIAM CARVALHO DE ANDRADE DA SILVA, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_base_advogados': 'ALEXANDRE GAMEIRO DE BRITO, CARLOS MARTINS DE OLIVEIRA, JULIO CEZAR COELHO FERRAZ, MARCUS VINICIUS FREITAS DA SILVA',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA, JEFFERSON FRANKLIN BATISTA DA SILVA',
#    'processo_base_juizes': 'Daniela Reetz de Paiva, Karen Marinho Rodrigues, Monique Abreu David',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte, Marcelo de Oliveira Hemerly'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1667650/',
#    'similaridade': 94.71,
#    'processo_base_tj': '2016.204.020058-0',
#    'processo_base_cnj': '0020166-62.2016.8.19.0204',
#    'processo_similar_tj': '2016.204.004382-6',
#    'processo_similar_cnj': '0004390-22.2016.8.19.0204',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Material - Outros',
#    'processo_similar_assunto': 'Rescisão do contrato e devolução do dinheiro',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'AMANDA CORRÊA DE SOUZA, SHOPFATO COMERCIO DE ELETRÔNICOS S/A',
#    'processo_similar_personagens': 'IRAN MELO CAMPOS, KPG COMERCIO DE EQUIPAMENTO PARA GASES LTDA (DEL GAS)',
#    'processo_base_advogados': 'EDUARDO GROSS, MONALISA DE ASSIS FERNANDES DETTOGNI DA CRUZ',
#    'processo_similar_advogados': 'ERIC BARROS XAVIER, HENRIQUE SAMPAIO FERREIRA, WANDIR BRASIL DE LIMA',
#    'processo_base_juizes': 'Ana Quezia Pereira de Freitas, Isabela Lobão dos Santos',
#    'processo_similar_juizes': 'Alexandre Jose da Silva Barbosa, Paloma Bispo dos Santos'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1632348/',
#    'similaridade': 94.71,
#    'processo_base_tj': '2016.204.004382-6',
#    'processo_base_cnj': '0004390-22.2016.8.19.0204',
#    'processo_similar_tj': '2016.204.020058-0',
#    'processo_similar_cnj': '0020166-62.2016.8.19.0204',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_base_assunto': 'Rescisão do contrato e devolução do dinheiro',
#    'processo_similar_assunto': 'Indenização Por Dano Material - Outros',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'IRAN MELO CAMPOS, KPG COMERCIO DE EQUIPAMENTO PARA GASES LTDA (DEL GAS)',
#    'processo_similar_personagens': 'AMANDA CORRÊA DE SOUZA, SHOPFATO COMERCIO DE ELETRÔNICOS S/A',
#    'processo_base_advogados': 'ERIC BARROS XAVIER, HENRIQUE SAMPAIO FERREIRA, WANDIR BRASIL DE LIMA',
#    'processo_similar_advogados': 'EDUARDO GROSS, MONALISA DE ASSIS FERNANDES DETTOGNI DA CRUZ',
#    'processo_base_juizes': 'Alexandre Jose da Silva Barbosa, Paloma Bispo dos Santos',
#    'processo_similar_juizes': 'Ana Quezia Pereira de Freitas, Isabela Lobão dos Santos'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1660852/',
#    'similaridade': 94.45,
#    'processo_base_tj': '2016.204.005638-9',
#    'processo_base_cnj': '0005653-89.2016.8.19.0204',
#    'processo_similar_tj': '2016.205.016006-2',
#    'processo_similar_cnj': '0016123-79.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Declaração de Inexistência de Débito e / Ou da Relação Jurídica',
#    'processo_similar_assunto': 'Inclusão Indevida em Cadastro de Inadimplentes',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'DANIEL REIS VIEIRA, FOZ ÁGUAS 5 - FAB ZONA OESTE S.A.',
#    'processo_similar_personagens': 'F.AB. ZONA OESTE S.A, MARIA MESQUITA SOARES',
#    'processo_base_advogados': 'ADRIANO MOTA CASSOL, RENATA NUNES MIRANDA',
#    'processo_similar_advogados': 'ADRIANO MOTA CASSOL, ADRIENE RODRIGUES VON RANDOW',
#    'processo_base_juizes': 'Cristiane Teles Moura Marques, Jefferson Albernaz Ferreira Ferraz',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte, Marcelo de Oliveira Hemerly'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1694574/',
#    'similaridade': 94.45,
#    'processo_base_tj': '2016.205.016006-2',
#    'processo_base_cnj': '0016123-79.2016.8.19.0205',
#    'processo_similar_tj': '2016.204.005638-9',
#    'processo_similar_cnj': '0005653-89.2016.8.19.0204',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_base_assunto': 'Inclusão Indevida em Cadastro de Inadimplentes',
#    'processo_similar_assunto': 'Declaração de Inexistência de Débito e / Ou da Relação Jurídica',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'F.AB. ZONA OESTE S.A, MARIA MESQUITA SOARES',
#    'processo_similar_personagens': 'DANIEL REIS VIEIRA, FOZ ÁGUAS 5 - FAB ZONA OESTE S.A.',
#    'processo_base_advogados': 'ADRIANO MOTA CASSOL, ADRIENE RODRIGUES VON RANDOW',
#    'processo_similar_advogados': 'ADRIANO MOTA CASSOL, RENATA NUNES MIRANDA',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte, Marcelo de Oliveira Hemerly',
#    'processo_similar_juizes': 'Cristiane Teles Moura Marques, Jefferson Albernaz Ferreira Ferraz'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1728452/',
#    'similaridade': 94.41,
#    'processo_base_tj': '2015.204.037087-2',
#    'processo_base_cnj': '0037273-56.2015.8.19.0204',
#    'processo_similar_tj': '2016.205.034967-5',
#    'processo_similar_cnj': '0035231-94.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Rescisão do contrato e devolução do dinheiro',
#    'processo_similar_assunto': 'Rescisão do contrato e devolução do dinheiro',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'JACK DESIGNER, NIVALDO CLAUDIO DE FREITAS, RIO DECOR RIO PETRÓPOLIS',
#    'processo_similar_personagens': 'BONBINI CAMPO GRANDE MÓVEIS E UTILIDADES LTDA., REALIZZE MÓVEIS PLANEJADOS, REGIANE DOS SANTOS CUNHA',
#    'processo_base_advogados': 'ANDRÉA PARADELA AUGUSTO, DENISE ANALIA BARELA CAETANO, HENRIQUE SAMPAIO FERREIRA, MICHELINE ALVES DE FREITAS, ROBERTA PAULA DOMINGOS MACEDO DA COSTA',
#    'processo_similar_advogados': 'ADALBERTO FONSATTI, BRENNO CUNHA MACHADO, KARINA SILVA CUNHA MACHADO, LEANDRO DAVID, TALES ANDRE FRANZIN',
#    'processo_base_juizes': 'Isabela Lobão dos Santos',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1667355/',
#    'similaridade': 94.09,
#    'processo_base_tj': '2015.205.045805-0',
#    'processo_base_cnj': '0046239-05.2015.8.19.0205',
#    'processo_similar_tj': '2015.205.045739-1',
#    'processo_similar_cnj': '0046175-92.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_similar_assunto': 'Pagamento Indevido',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'LILIANE SOARES MARTINS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'ANA MARIA DE ARAUJO, SKY BRASIL SERVIÇOS LTDA',
#    'processo_base_advogados': 'CARLOS MARTINS DE OLIVEIRA, SEBASTIÃO RODRIGUES DOS SANTOS',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA',
#    'processo_base_juizes': 'Bianca Ferreira do Amaral Machado Nigri',
#    'processo_similar_juizes': 'Bianca Ferreira do Amaral Machado Nigri, Marcelo de Oliveira Hemerly'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1663739/',
#    'similaridade': 94.09,
#    'processo_base_tj': '2015.205.045739-1',
#    'processo_base_cnj': '0046175-92.2015.8.19.0205',
#    'processo_similar_tj': '2015.205.045805-0',
#    'processo_similar_cnj': '0046239-05.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_base_assunto': 'Pagamento Indevido',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'ANA MARIA DE ARAUJO, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'LILIANE SOARES MARTINS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_base_advogados': 'CARLOS MARTINS DE OLIVEIRA',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA, SEBASTIÃO RODRIGUES DOS SANTOS',
#    'processo_base_juizes': 'Bianca Ferreira do Amaral Machado Nigri, Marcelo de Oliveira Hemerly',
#    'processo_similar_juizes': 'Bianca Ferreira do Amaral Machado Nigri'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1731431/',
#    'similaridade': 94.04,
#    'processo_base_tj': '2016.205.039786-4',
#    'processo_base_cnj': '0040029-98.2016.8.19.0205',
#    'processo_similar_tj': '2016.204.024708-0',
#    'processo_similar_cnj': '0024870-21.2016.8.19.0204',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outros',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'LEANDRO CARVALHO DA SILVA, MF EVOLUÇÃO GNV LTDA, PNEUMATICOS JANAPAT LTDA',
#    'processo_similar_personagens': 'ROBERTA LOPES, SHOPFACIL.COM.BR',
#    'processo_base_advogados': 'ALEX MEDINA ALVES, CAMILO DE SOUZA CAMILO',
#    'processo_similar_advogados': None,
#    'processo_base_juizes': 'Ana Beatriz de Carvalho Barbosa Moreira, Renata Guarino Martins',
#    'processo_similar_juizes': 'Isabela Lobão dos Santos'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1697673/',
#    'similaridade': 94.03,
#    'processo_base_tj': '2015.205.047558-7',
#    'processo_base_cnj': '0048002-41.2015.8.19.0205',
#    'processo_similar_tj': '2015.205.048491-6',
#    'processo_similar_cnj': '0048942-06.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Cobrança de Quantia Indevida',
#    'processo_similar_assunto': 'Declaração de Inexistência de Débito e / Ou da Relação Jurídica',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'LUCIMERE DE LIMA LINS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'DENILSA DO ROSARIO SANTOS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_base_advogados': 'ELIAS BATISTA ROSS JUNIOR',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA, ELISÂNGELA PORTUGAL DE SOUTO PEREIRA',
#    'processo_base_juizes': 'Renata Guarino Martins, Samyra Remzetti Bernardi',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte, Jamille Vieira de Carvalho Perez'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1765583/',
#    'similaridade': 94.03,
#    'processo_base_tj': '2015.205.048491-6',
#    'processo_base_cnj': '0048942-06.2015.8.19.0205',
#    'processo_similar_tj': '2015.205.047558-7',
#    'processo_similar_cnj': '0048002-41.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_base_assunto': 'Declaração de Inexistência de Débito e / Ou da Relação Jurídica',
#    'processo_similar_assunto': 'Cobrança de Quantia Indevida',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'DENILSA DO ROSARIO SANTOS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'LUCIMERE DE LIMA LINS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_base_advogados': 'CARLOS MARTINS DE OLIVEIRA, ELISÂNGELA PORTUGAL DE SOUTO PEREIRA',
#    'processo_similar_advogados': 'ELIAS BATISTA ROSS JUNIOR',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte, Jamille Vieira de Carvalho Perez',
#    'processo_similar_juizes': 'Renata Guarino Martins, Samyra Remzetti Bernardi'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1702390/',
#    'similaridade': 93.98,
#    'processo_base_tj': '2016.205.018950-7',
#    'processo_base_cnj': '0019068-39.2016.8.19.0205',
#    'processo_similar_tj': '2016.205.011584-6',
#    'processo_similar_cnj': '0011602-91.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'ANGELO RANGEL ALENCAR, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_similar_personagens': 'MIRIAM CARVALHO DE ANDRADE DA SILVA, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_base_advogados': 'CARLOS MARTINS DE OLIVEIRA, MÁRIO LUÍS SOARES RIBEIRO',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA, JEFFERSON FRANKLIN BATISTA DA SILVA',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte, Marcelo de Oliveira Hemerly'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1702749/',
#    'similaridade': 93.98,
#    'processo_base_tj': '2016.205.016636-2',
#    'processo_base_cnj': '0016752-53.2016.8.19.0205',
#    'processo_similar_tj': '2016.205.011584-6',
#    'processo_similar_cnj': '0011602-91.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Antecipação de Tutela / Tutela Específica',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'ADAILTON LUIS AUGUSTO CAMPOS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'MIRIAM CARVALHO DE ANDRADE DA SILVA, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_base_advogados': 'BRUNO CARREIRA GUIMARAES, CARLOS MARTINS DE OLIVEIRA',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA, JEFFERSON FRANKLIN BATISTA DA SILVA',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte, Marcelo de Oliveira Hemerly'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1702786/',
#    'similaridade': 93.95,
#    'processo_base_tj': '2016.204.014204-0',
#    'processo_base_cnj': '0014255-69.2016.8.19.0204',
#    'processo_similar_tj': '2015.205.048491-6',
#    'processo_similar_cnj': '0048942-06.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Cobrança de Quantia Indevida',
#    'processo_similar_assunto': 'Declaração de Inexistência de Débito e / Ou da Relação Jurídica',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'FABRICIA LIRA GONÇALVES, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_similar_personagens': 'DENILSA DO ROSARIO SANTOS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_base_advogados': 'ALEXANDRE GAMEIRO DE BRITO, CARLOS MARTINS DE OLIVEIRA, JULIO CEZAR COELHO FERRAZ, MARCUS VINICIUS FREITAS DA SILVA',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA, ELISÂNGELA PORTUGAL DE SOUTO PEREIRA',
#    'processo_base_juizes': 'Daniela Reetz de Paiva, Karen Marinho Rodrigues, Monique Abreu David',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte, Jamille Vieira de Carvalho Perez'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1737437/',
#    'similaridade': 93.95,
#    'processo_base_tj': '2015.205.048491-6',
#    'processo_base_cnj': '0048942-06.2015.8.19.0205',
#    'processo_similar_tj': '2016.204.014204-0',
#    'processo_similar_cnj': '0014255-69.2016.8.19.0204',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Bangu',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_base_assunto': 'Declaração de Inexistência de Débito e / Ou da Relação Jurídica',
#    'processo_similar_assunto': 'Cobrança de Quantia Indevida',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'DENILSA DO ROSARIO SANTOS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'FABRICIA LIRA GONÇALVES, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_base_advogados': 'CARLOS MARTINS DE OLIVEIRA, ELISÂNGELA PORTUGAL DE SOUTO PEREIRA',
#    'processo_similar_advogados': 'ALEXANDRE GAMEIRO DE BRITO, CARLOS MARTINS DE OLIVEIRA, JULIO CEZAR COELHO FERRAZ, MARCUS VINICIUS FREITAS DA SILVA',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte, Jamille Vieira de Carvalho Perez',
#    'processo_similar_juizes': 'Daniela Reetz de Paiva, Karen Marinho Rodrigues, Monique Abreu David'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1772556/',
#    'similaridade': 93.94,
#    'processo_base_tj': '2015.205.042869-0',
#    'processo_base_cnj': '0043301-37.2015.8.19.0205',
#    'processo_similar_tj': '2015.205.045805-0',
#    'processo_similar_cnj': '0046239-05.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_base_assunto': 'Cobrança de Quantia Indevida',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'BRUNO ALBERTO GARCIA FERREIRA, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'LILIANE SOARES MARTINS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_base_advogados': 'CARLOS MARTINS DE OLIVEIRA, MARCUS VINÍCIUS VIOLA FERREIRA',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA, SEBASTIÃO RODRIGUES DOS SANTOS',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte',
#    'processo_similar_juizes': 'Bianca Ferreira do Amaral Machado Nigri'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1807719/',
#    'similaridade': 93.86,
#    'processo_base_tj': '2016.204.028823-9',
#    'processo_base_cnj': '0029062-94.2016.8.19.0204',
#    'processo_similar_tj': '2016.205.011584-6',
#    'processo_similar_cnj': '0011602-91.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 17º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização por Dano Material',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'DEBORA PEREIRA DA SILVA, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_similar_personagens': 'MIRIAM CARVALHO DE ANDRADE DA SILVA, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_base_advogados': 'MONIQUE PEREIRA DE LUNA',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA, JEFFERSON FRANKLIN BATISTA DA SILVA',
#    'processo_base_juizes': 'Isabela Lobão dos Santos',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte, Marcelo de Oliveira Hemerly'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1737898/',
#    'similaridade': 93.8,
#    'processo_base_tj': '2016.205.011584-6',
#    'processo_base_cnj': '0011602-91.2016.8.19.0205',
#    'processo_similar_tj': '2015.205.048491-6',
#    'processo_similar_cnj': '0048942-06.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outras',
# ...
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_similar_assunto': 'Declaração de Inexistência de Débito e / Ou da Relação Jurídica',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'ANGELO RANGEL ALENCAR, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_similar_personagens': 'DENILSA DO ROSARIO SANTOS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_base_advogados': 'CARLOS MARTINS DE OLIVEIRA, MÁRIO LUÍS SOARES RIBEIRO',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA, ELISÂNGELA PORTUGAL DE SOUTO PEREIRA',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte, Jamille Vieira de Carvalho Perez'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/2115014/',
#    'similaridade': 93.08,
#    'processo_base_tj': '2015.205.036995-7',
#    'processo_base_cnj': '0037367-98.2015.8.19.0205',
#    'processo_similar_tj': '2015.205.048626-3',
#    'processo_similar_cnj': '0049078-03.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outros',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'JOSÉ FIRMO GONÇALVES, TELEMAR',
#    'processo_similar_personagens': 'GERALDO FERNANDES FIGUEIREDO DE AZEVEDO, OI MÓVEL S/A (EM RECUPERAÇÃO JUDICIAL)',
#    'processo_base_advogados': 'LEONARDO LAUREANO LOPES, RICARDO MAGALHÃES PINTO',
#    'processo_similar_advogados': 'RICARDO MAGALHÃES PINTO',
#    'processo_base_juizes': 'Marcelo de Oliveira Hemerly, Renata Guarino Martins',
#    'processo_similar_juizes': 'Joana Elena Dornas, Renata Guarino Martins'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/2150096/',
#    'similaridade': 93.04,
#    'processo_base_tj': '2015.205.051032-0',
#    'processo_base_cnj': '0051481-42.2015.8.19.0205',
#    'processo_similar_tj': '2015.205.043808-6',
#    'processo_similar_cnj': '0044238-47.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outros',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'EDGARD JOSÉ DA SILVA, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'JULIANA SILVA DE SA, SKY BRASIL SERVICOS LTDA',
#    'processo_base_advogados': 'ADRIANA COSTA PEREIRA',
#    'processo_similar_advogados': 'MARCIO VERON DOS SANTOS',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte, Rodrigo Marcos Ferreira Rodrigues'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/2185297/',
#    'similaridade': 93.04,
#    'processo_base_tj': '2016.205.020855-1',
#    'processo_base_cnj': '0021019-68.2016.8.19.0205',
#    'processo_similar_tj': '2015.205.048491-6',
#    'processo_similar_cnj': '0048942-06.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outros',
#    'processo_similar_assunto': 'Declaração de Inexistência de Débito e / Ou da Relação Jurídica',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'SKY BRASIL - SERVIÇOS LTDA - DIRECTV, VERA LUCIA RODRIGUES RIBEIRO',
#    'processo_similar_personagens': 'DENILSA DO ROSARIO SANTOS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_base_advogados': 'CARLOS MARTINS DE OLIVEIRA, DEFENSOR PÚBLICO',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA, ELISÂNGELA PORTUGAL DE SOUTO PEREIRA',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte, Renan Vieira Aniceto',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte, Jamille Vieira de Carvalho Perez'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/2216909/',
#    'similaridade': 93.04,
#    'processo_base_tj': '2015.205.048491-6',
#    'processo_base_cnj': '0048942-06.2015.8.19.0205',
#    'processo_similar_tj': '2016.205.020855-1',
#    'processo_similar_cnj': '0021019-68.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Declaração de Inexistência de Débito e / Ou da Relação Jurídica',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outros',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'DENILSA DO ROSARIO SANTOS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'SKY BRASIL - SERVIÇOS LTDA - DIRECTV, VERA LUCIA RODRIGUES RIBEIRO',
#    'processo_base_advogados': 'CARLOS MARTINS DE OLIVEIRA, ELISÂNGELA PORTUGAL DE SOUTO PEREIRA',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA, DEFENSOR PÚBLICO',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte, Jamille Vieira de Carvalho Perez',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte, Renan Vieira Aniceto'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/2183495/',
#    'similaridade': 93.04,
#    'processo_base_tj': '2016.205.006197-7',
#    'processo_base_cnj': '0006195-07.2016.8.19.0205',
#    'processo_similar_tj': '2015.205.054469-0',
#    'processo_similar_cnj': '0054922-31.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_base_assunto': 'Cobrança Indevida Telefonia Fixa - Plano de Franquia/serviço - Sem Solicitação do Usuário.',
#    'processo_similar_assunto': 'Cobrança Indevida Telefonia Fixa - Plano de Franquia/serviço - Sem Solicitação do Usuário.',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'PRISCILA MONTEIRO DE PINHO ARAUJO, TELEMAR NORTE LESTE S/A (EM RECUPERAÇÃO JUDICIAL)',
#    'processo_similar_personagens': 'CAMILA PACHECO MAGALHÃES DA SILVA, OI - TELEMAR NORTE LESTE',
#    'processo_base_advogados': 'ESTHER GAMA DE VASCONCELOS, RICARDO MAGALHÃES PINTO',
#    'processo_similar_advogados': 'IVSON UMBELINO DE LIMA, RICARDO MAGALHÃES PINTO',
#    'processo_base_juizes': 'Paulo Douglas Alexandrino Knupp, Renata Guarino Martins',
#    'processo_similar_juizes': 'Joana Elena Dornas, Renata Guarino Martins'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/2150297/',
#    'similaridade': 93.04,
#    'processo_base_tj': '2015.205.054469-0',
#    'processo_base_cnj': '0054922-31.2015.8.19.0205',
#    'processo_similar_tj': '2016.205.006197-7',
#    'processo_similar_cnj': '0006195-07.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_base_assunto': 'Cobrança Indevida Telefonia Fixa - Plano de Franquia/serviço - Sem Solicitação do Usuário.',
#    'processo_similar_assunto': 'Cobrança Indevida Telefonia Fixa - Plano de Franquia/serviço - Sem Solicitação do Usuário.',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'CAMILA PACHECO MAGALHÃES DA SILVA, OI - TELEMAR NORTE LESTE',
#    'processo_similar_personagens': 'PRISCILA MONTEIRO DE PINHO ARAUJO, TELEMAR NORTE LESTE S/A (EM RECUPERAÇÃO JUDICIAL)',
#    'processo_base_advogados': 'IVSON UMBELINO DE LIMA, RICARDO MAGALHÃES PINTO',
#    'processo_similar_advogados': 'ESTHER GAMA DE VASCONCELOS, RICARDO MAGALHÃES PINTO',
#    'processo_base_juizes': 'Joana Elena Dornas, Renata Guarino Martins',
#    'processo_similar_juizes': 'Paulo Douglas Alexandrino Knupp, Renata Guarino Martins'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/2185215/',
#    'similaridade': 93.02,
#    'processo_base_tj': '2015.205.050610-9',
#    'processo_base_cnj': '0051061-37.2015.8.19.0205',
#    'processo_similar_tj': '2016.205.044345-0',
#    'processo_similar_cnj': '0044606-22.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outros',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'RODRIGO DA SILVA ROSA, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'IRIS PEREIRA MEDINA DE BRITTO, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_base_advogados': 'CARLOS MARTINS DE OLIVEIRA, MONICA PAPERA DA SILVA',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/2185446/',
#    'similaridade': 93.01,
#    'processo_base_tj': '2015.205.051032-0',
#    'processo_base_cnj': '0051481-42.2015.8.19.0205',
#    'processo_similar_tj': '2015.205.047558-7',
#    'processo_similar_cnj': '0048002-41.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_similar_assunto': 'Cobrança de Quantia Indevida',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'EDGARD JOSÉ DA SILVA, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'LUCIMERE DE LIMA LINS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_base_advogados': 'ADRIANA COSTA PEREIRA',
#    'processo_similar_advogados': 'ELIAS BATISTA ROSS JUNIOR',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte',
#    'processo_similar_juizes': 'Renata Guarino Martins, Samyra Remzetti Bernardi'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/2220342/',
#    'similaridade': 92.99,
#    'processo_base_tj': '2016.205.016636-2',
#    'processo_base_cnj': '0016752-53.2016.8.19.0205',
#    'processo_similar_tj': '2016.205.044345-0',
#    'processo_similar_cnj': '0044606-22.2016.8.19.0205',
#    'processo_base_comarca': 'Regional de Campo Grande',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 18º Juizado Especial Cível',
#    'processo_base_assunto': 'Antecipação de Tutela / Tutela Específica',
#    'processo_similar_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'ADAILTON LUIS AUGUSTO CAMPOS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'IRIS PEREIRA MEDINA DE BRITTO, SKY BRASIL - SERVIÇOS LTDA - DIRECTV',
#    'processo_base_advogados': 'BRUNO CARREIRA GUIMARAES, CARLOS MARTINS DE OLIVEIRA',
#    'processo_similar_advogados': 'CARLOS MARTINS DE OLIVEIRA',
#    'processo_base_juizes': 'Anelise de Faria Martorell Duarte',
#    'processo_similar_juizes': 'Anelise de Faria Martorell Duarte'},
#   {'id': 'http://0.0.0.0:8000/api/models/processossimilaresreport/1562116/',
#    'similaridade': 92.98,
#    'processo_base_tj': '2015.204.038399-4',
#    'processo_base_cnj': '0038584-82.2015.8.19.0204',
#    'processo_similar_tj': '2015.205.047558-7',
#    'processo_similar_cnj': '0048002-41.2015.8.19.0205',
#    'processo_base_comarca': 'Regional de Bangu',
#    'processo_similar_comarca': 'Regional de Campo Grande',
#    'processo_base_serventia': 'Cartório do 29º Juizado Especial Cível',
#    'processo_similar_serventia': 'Cartório do 26º Juizado Especial Cível',
#    'processo_base_assunto': 'Indenização Por Dano Moral - Outras',
#    'processo_similar_assunto': 'Cobrança de Quantia Indevida',
#    'processo_base_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_similar_classe': 'Procedimento do Juizado Especial Cível',
#    'processo_base_competencia': 'Juizado Especial Cível',
#    'processo_similar_competencia': 'Juizado Especial Cível',
#    'processo_base_personagens': 'PATRICIA FERREIRA PONTES, SKY BRASIL SERVIÇOS LTDA',
#    'processo_similar_personagens': 'LUCIMERE DE LIMA LINS, SKY BRASIL SERVIÇOS LTDA',
#    'processo_base_advogados': 'ELIZANGELA LABRE BERTOLINO DE OLIVEIRA SANTOS',
#    'processo_similar_advogados': 'ELIAS BATISTA ROSS JUNIOR',
#    'processo_base_juizes': 'Monique Abreu David',
#    'processo_similar_juizes': 'Renata Guarino Martins, Samyra Remzetti Bernardi'}]}

# %%
a = re.search(r'\?page=(\d+)','http://0.0.0.0:8000/api/models/processossimilaresreport/?page=1')

# %%
a.group(1)
# Out:
# '1'
